# %%
from IPython.display import display, HTML

html_code = """
<!DOCTYPE html>
<html>
<head>
<style>
    body{
        font-family: Arial, sans-serif;
        background:#f3f5fa;
        padding:20px;
    }

    .card{
        background:white;
        width:350px;
        margin:auto;
        padding:25px;
        border-radius:20px;
        box-shadow:0 4px 15px rgba(0,0,0,0.1);
    }

    .top{
        display:flex;
        justify-content:space-between;
        align-items:center;
    }

    .number{
        background:#e9f0ff;
        color:#005eff;
        padding:15px 20px;
        border-radius:15px;
        font-size:28px;
        font-weight:bold;
    }

    .status{
        background:#eef4ff;
        color:#1d4ed8;
        padding:10px 18px;
        border-radius:20px;
        font-weight:bold;
    }

    .due{
        margin-top:25px;
        display:flex;
        justify-content:space-between;
        align-items:center;
        font-size:18px;
    }

    .days{
        background:#c8ffe4;
        color:#008a5c;
        padding:10px 18px;
        border-radius:20px;
        font-weight:bold;
    }

    h1{
        margin-top:30px;
        color:#0f172a;
        font-size:34px;
    }

    p{
        color:#555;
        line-height:1.7;
        font-size:18px;
    }

    .title{
        color:#005eff;
        font-size:24px;
        font-weight:bold;
        margin-top:20px;
    }

    ul{
        color:#555;
        line-height:1.8;
        font-size:18px;
    }

    .green{
        color:#00a86b;
        font-size:24px;
        font-weight:bold;
        margin-top:20px;
    }

    button{
        margin-top:30px;
        background:#005eff;
        color:white;
        border:none;
        padding:16px 30px;
        border-radius:15px;
        font-size:20px;
        font-weight:bold;
        cursor:pointer;
    }

    button:hover{
        background:#0042b8;
    }
</style>
</head>

<body>

<div class="card">

    <div class="top">
        <div class="number">5</div>
        <div class="status">AVAILABLE</div>
    </div>

    <div class="due">
        <div><b>Due Date:</b> 31 May 2026</div>
        <div class="days">7 Days Left</div>
    </div>

    <h1>Full-Stack Deployment & Project Architecture</h1>

    <p>
        Combine all prior knowledge to build, optimize,
        and deploy a comprehensive Web Development
        Capstone Project.
    </p>

    <div class="title">Key Features:</div>

    <ul>
        <li>Architect a modular frontend application</li>
        <li>Implement client-side routing</li>
        <li>Optimize assets for performance</li>
        <li>Deploy application live to platform</li>
    </ul>

    <div class="green">Expected Outcome:</div>

    <p>
        A live, production-ready web application
        with a public URL.
    </p>

    <center>
        <button>Submit Work</button>
    </center>

</div>

</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#     body{
#         font-family: Arial, sans-serif;
#         background:#f3f5fa;
#         padding:20px;
#     }
#
#     .card{
#         background:white;
#         width:350px;
#         margin:auto;
#         padding:25px;
#         border-radius:20px;
#         box-shadow:0 4px 15px rgba(0,0,0,0.1);
#     }
#
#     .top{
#         display:flex;
#         justify-content:space-between;
#         align-items:center;
#     }
#
#     .number{
#         background:#e9f0ff;
#         color:#005eff;
#         padding:15px 20px;
#         border-radius:15px;
#         font-size:28px;
#         font-weight:bold;
#     }
#
#     .status{
#         background:#eef4ff;
#         color:#1d4ed8;
#         padding:10px 18px;
#         border-radius:20px;
#         font-weight:bold;
#     }
#
#     .due{
#         margin-top:25px;
#         display:flex;
#         justify-content:space-between;
#         align-items:center;
# ...
